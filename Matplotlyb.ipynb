# %% [markdown]
# # Matplotlyb

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Para crear un gráfico con matplotlib es habitual seguir los siguientes pasos:
# 1. Definir la figura que contendrá el gráfico, que es la region (ventana o página) donde se dibujará y los ejes sobre los que se dibujarán los datos. Para ello se utiliza la función subplots().
# 2. Dibujar los datos sobre los ejes. Para ello se utilizan distintas funciones dependiendo del tipo de gráfico que se quiera.
# 3. Personalizar el gráfico. Para ello existen multitud de funciones que permiten añadir un título, una leyenda, una rejilla, cambiar colores o personalizar los ejes.
#
# 4. Guardar el gráfico. Para ello se utiliza la función savefig().
# 5. Mostrar el gráfico. Para ello se utiliza la función show().

# %% [markdown]
# El elemento fig es el marco del grafico que creemos, podemos pensar en ello como el lienzo del histograma. Para poder funcionar correctamente, una figura necesita un marco sobre el cual graficar. Esto se puede realizar con el metodo subplots()

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ### Limitar rango de valores
# Se puede limitar el rango de valores tanto del eje x como del y

# %%
ax.set_xlim(0, 150)
ax.set_ylim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ### Titulos de los ejes

# %%
ax.set_ylabel("Poblacion")
ax.set_xlabel("Area")
fig

# %% [markdown]
# ## Diagrama de dispersión
# scatter(x, y): Dibuja un diagrama de puntos con las coordenadas de la lista x en el eje X y las coordenadas de la lista y en el eje Y.

# %%
import numpy as np
fig, ax = plt.subplots()
x = np.array([1, 2, 3, 4])
y = np.array([[1, 2, 0, 0.5]])
ax.scatter(x,y)
plt.show()

# %% [markdown]
# ## Histogramas
# hist(x, bins): Dibuja un histograma con las frecuencias resultantes de agrupar los datos de la lista x en las clases definidas por la lista bins.
# bins puede recibir tanto un numero que indique el numero de clases o un array que indique los limites de esas clases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots()
x = np.random.normal(5, 1.5, size=1000)
#np.arange(0, 11) genera una lista con elementos del 0 al 11
ax.hist(x, np.arange(0, 11))
plt.show()

# %%
fig, ax = plt.subplots()
x = np.random.normal(5, 1.5, size=1000)
ax.hist(x, 12)
plt.show()
